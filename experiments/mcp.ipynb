# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain.chat_models import ChatOpenAI

# %%
import langchain
print(langchain.__version__)
# Out:
# 0.2.17

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
KEY=os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
llm = ChatOpenAI(openai_api_key=KEY,model_name="gpt-3.5-turbo", temperature=0.3)
